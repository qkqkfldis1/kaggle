# %%
import pandas as pd

# %%
train = pd.read_csv('train.csv').fillna(0)
print(train.axes)
def SexToNum(dfTemp):
    if dfTemp['Sex'] == 'male':
        return 0
    if dfTemp['Sex'] == 'female':
        return 1

def EmbarkedToNum(dfTemp):
    if dfTemp['Embarked'] == 'C':
        return 0
    elif dfTemp['Embarked'] == 'S':
        return 1
    elif dfTemp['Embarked'] == 'Q':
        return 2
    else:
        return 3
df_train['PassengerId'] = train['PassengerId']
df_train['Pclass'] = train['Pclass']
df_train['Age'] = train['Age']
df_train['SibSp'] = train['SibSp']
df_train['Parch'] = train['Parch']
df_train['Fare'] = train['Fare']
df_train['Sex'] = train.apply(SexToNum, axis=1)
df_train['Survived'] = train['Survived']
# Out:
# [RangeIndex(start=0, stop=891, step=1), Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')]

# %%
df
# Out:
#      Sex  PassengerId  Pclass   Age  SibSp  Parch      Fare  Survived
# 0      0            1       3  22.0      1      0    7.2500         0
# 1      1            2       1  38.0      1      0   71.2833         1
# 2      1            3       3  26.0      0      0    7.9250         1
# 3      1            4       1  35.0      1      0   53.1000         1
# 4      0            5       3  35.0      0      0    8.0500         0
# 5      0            6       3   0.0      0      0    8.4583         0
# 6      0            7       1  54.0      0      0   51.8625         0
# 7      0            8       3   2.0      3      1   21.0750         0
# 8      1            9       3  27.0      0      2   11.1333         1
# 9      1           10       2  14.0      1      0   30.0708         1
# 10     1           11       3   4.0      1      1   16.7000         1
# 11     1           12       1  58.0      0      0   26.5500         1
# ...

# %%
train = pd.read_csv('test.csv').fillna(0)
print(train.axes)
def SexToNum(dfTemp):
    if dfTemp['Sex'] == 'male':
        return 0
    if dfTemp['Sex'] == 'female':
        return 1

def EmbarkedToNum(dfTemp):
    if dfTemp['Embarked'] == 'C':
        return 0
    elif dfTemp['Embarked'] == 'S':
        return 1
    elif dfTemp['Embarked'] == 'Q':
        return 2
    else:
        return 3
df_test['PassengerId'] = train['PassengerId']
df_test['Pclass'] = train['Pclass']
df_test['Age'] = train['Age']
df_test['SibSp'] = train['SibSp']
df_test['Parch'] = train['Parch']
df_test['Fare'] = train['Fare']
df_test['Sex'] = train.apply(SexToNum, axis=1)
df_test['Survived'] = train['Survived']
